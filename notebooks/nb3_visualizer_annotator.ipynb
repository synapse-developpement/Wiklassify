# %% [markdown]
# # Visualization and annotation

# %% [markdown]
# This notebook shows all steps for helping the annotator in the labelling task.

# %%
import numpy as np
import pandas as pd
import sys
import re
import xml.sax
import time
import datetime
from colorama import init, Fore, Back, Style
from time import time, gmtime, strftime
from datetime import datetime
from tqdm import tqdm
from sklearn.metrics import cohen_kappa_score

# can display several outputs from a single code cell
from IPython.core.interactiveshell import InteractiveShell 
InteractiveShell.ast_node_interactivity = "all"

# change display of pandas df
#pd.set_option('display.height', 1000)
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 500)
#pd.set_option('display.width', 1000)

# %% [markdown]
# (OPTIONAL)<br>
# Disable scrolling output window mode (useful for display long list of results)

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %% [markdown]
# (OPTIONAL)<br>
# Resume scrolling output window mode

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return true;
# }

# %% [markdown]
# ## Dataframe visualizer

# %% [markdown]
# Load datasets (one .tsv file usually contains 100 samples or version pairs).

# %%
sample_tsv_file = '00_09_73_sample.tsv'
df_sample = pd.read_csv('/media/hdd/salaun/wikiedit/annotations/data_v1/' + sample_tsv_file, sep='\t')

#df_sample = df_sample.drop('Unnamed: 0', 1)
df_sample = df_sample.fillna('')
df_sample.shape
df_sample.columns
df_sample.head()
# Out:
# (100, 35)
# Index(['Unnamed: 0', 'sample_id', 'id_file', 'id_modif', 'label_incoherence',
#        'username', 'user_id', 'registered', 'format', 'model', 'id',
#        'parentid', 'title', 'minor', 'comment', 'modif', 'modif_remove',
#        'modif_add', 'timestamp', 'filt_bot', 'filt_coher', 'filt_confli',
#        'filt_contradic', 'filt_erreur', 'filt_erron', 'filt_faux',
#        'filt_frappe', 'filt_gramma', 'filt_ortho', 'filt_revert', 'filt_sens',
#        'filt_tromp', 'filt_typo', 'filt_vandalisme', 'filt_vraise'],
#       dtype='object')
#    Unnamed: 0        sample_id  id_file  id_modif  label_incoherence  \
# 0           0   p3p3661_181737  p3p3661    181737              False
# 1           1  p3p3661_1115892  p3p3661   1115892              False
# 2           2   p3p3661_248902  p3p3661    248902              False
# 3           3   p3p3661_931556  p3p3661    931556              False
# 4           4   p3p3661_494479  p3p3661    494479              False
#
#          username user_id  registered       format     model         id  \
# 0  196.28.255.210               False  text/x-wiki  wikitext   23653486
# 1           Skiff  242536        True  text/x-wiki  wikitext  124685050
# 2   178.194.81.42               False  text/x-wiki  wikitext  106009920
# 3            Zedh  132668        True  text/x-wiki  wikitext   17836113
# 4        Authueil  142917        True  text/x-wiki  wikitext  135511369
#
#     parentid                   title  minor  \
# 0   23640882            Burkina Faso  False
# 1  124685017                  Soudan  False
# 2  105780947  Château de Pierrefonds  False
# 3   17807973          Paire torsadée  False
# 4  135511330                  Guinée  False
#
#                                              comment  \
# 0                               /* Administration */
# 1                                    /* {{s-|XX}} */
# 2      /* Un monument en constante transformation */
# 3     /* Catégorie 5e */ corr baclée (je repasserai)
# 4  Annulation de la [[Spécial:Diff/135511330|modi...
#
#                                                modif  \
# 0  - Le territoire du Burkina Faso est réparti en...
# 1  - En septembre [[1983]] le président Nimeiri a...
# 2  - Ouverts au public sous le Second Empire comm...
# 3  + La catégorie 5e (''enhanced'') est un type d...
# 4  - Le mil et le fonio sont les principales cult...
#
#                                         modif_remove  \
# 0  Le territoire du Burkina Faso est réparti en 4...
# 1  En septembre [[1983]] le président Nimeiri ann...
# 2  Ouverts au public sous le Second Empire comme ...
# 3  La catégorie 5e (''enhanced'') est un type de ...
# 4  Le mil et le fonio sont les principales cultur...
#
#                                            modif_add             timestamp  \
# 0  Le territoire du Burkina Faso est réparti en 4...  2007-12-04T10:39:19Z
# 1  En septembre [[1983]], le président Nimeiri an...  2016-03-25T04:39:21Z
# 2  Ouverts au public sous le Second Empire comme ...  2014-08-05T11:28:00Z
# 3  La catégorie 5e (''enhanced'') est un type de ...  2007-06-12T16:03:04Z
# 4  Le mil et le fonio sont les principales cultur...  2017-03-17T18:57:49Z
#
#    filt_bot  filt_coher  filt_confli  filt_contradic  filt_erreur  filt_erron  \
# 0      True       False        False           False        False       False
# 1      True       False        False           False        False       False
# 2      True       False        False           False        False       False
# 3      True       False        False           False        False       False
# 4      True       False        False           False        False       False
#
#    filt_faux  filt_frappe  filt_gramma  filt_ortho  filt_revert  filt_sens  \
# 0      False        False        False       False        False      False
# 1      False        False        False       False        False      False
# 2      False        False        False       False        False      False
# 3      False        False        False       False        False      False
# 4      False        False        False       False        False      False
#
#    filt_tromp  filt_typo  filt_vandalisme  filt_vraise
# 0       False      False            False        False
# 1       False      False            False        False
# 2       False      False            False        False
# 3       False      False            False        False
# 4       False      False            False        False

# %% [markdown]
# Display all relevant information from <code>df_sample</code> entries with a reader-friendly interface. One can comment/uncomment elements depending on what features she needs. Usually one displays urls (<code>link</code>) for a better visualization of Wikipedia edits.
# For annotation task, process .csv files in **InterfaceAnnotation.exe** that will return eventually return a .csv file with all labels. That .csv file name shall contain the substring *post_annot* .

# %%
for row in range(0, len(df_sample)):

    print('sample_id', '\t', df_sample.loc[row, 'sample_id'])
    print(Style.BRIGHT + Fore.WHITE + 'timestamp', '\t', df_sample.loc[row, 'timestamp'] + Style.RESET_ALL)
    print('\n') 

    #print('minor_modif', '\t', df_sample.loc[row, 'minor'])
    print(Style.BRIGHT + Fore.RED + 'username', '\t', df_sample.loc[row, 'username'] + Style.RESET_ALL) 
    
    if df_sample.loc[row, 'registered']:
        print('\t','\t', Style.BRIGHT + Fore.WHITE + '>>> registered user' + Style.RESET_ALL)
    else:
        print('\t','\t', Style.BRIGHT + Fore.WHITE + '>>> NON registered user' + Style.RESET_ALL, '\n')

    
    if df_sample.loc[row, 'minor']:
        print('\n','\t','\t', Style.BRIGHT + Fore.WHITE + '# MINOR MODIF' + Style.RESET_ALL)
    else:
        pass
    
    print(Style.BRIGHT + Fore.RED + 'comment', '\t', df_sample.loc[row, 'comment'] + Style.RESET_ALL, '\n')
    
    print('title   ' , '\t', Style.BRIGHT + Fore.BLUE + df_sample.loc[row, 'title'] + Style.RESET_ALL)
    print('link     ', '\t', 'https://fr.wikipedia.org/w/index.php?diff=' + str(df_sample.loc[row, 'id']) + '&oldid=' + str(df_sample.loc[row, 'parentid']), '\n')
    
    # display text versions
    #print(df_sample.loc[row, 'modif'] + '\n' + '_'*80)
    #print(df_sample.loc[row, 'modif_remove'] + '\n' + '_'*80)
    #print(df_sample.loc[row, 'modif_add'] + '\n' + '_'*80)

    print('\n'*2)
    print('_'*83)
    print('_'*35 + 'Remaining items: ' + str(len(df_sample) - 1 - row) + '_'*35)
    print('_'*83)
    print('\n'*2)
# Out:
# sample_id 	 p3p3661_181737
# timestamp 	 2007-12-04T10:39:19Z
#
#
# username 	 196.28.255.210
# 	 	 >>> NON registered user
#
# comment 	 /* Administration */
#
# title    	 Burkina Faso
# link      	 https://fr.wikipedia.org/w/index.php?diff=23653486&oldid=23640882
#
#
#
#
# ___________________________________________________________________________________
# ___________________________________Remaining items: 99___________________________________
# ___________________________________________________________________________________
#
#
#
# sample_id 	 p3p3661_1115892
# timestamp 	 2016-03-25T04:39:21Z
#
#
# username 	 Skiff
# 	 	 >>> registered user
# comment 	 /* {{s-|XX}} */
#
# title    	 Soudan
# link      	 https://fr.wikipedia.org/w/index.php?diff=124685050&oldid=124685017
#
#
#
#
# ___________________________________________________________________________________
# ___________________________________Remaining items: 98___________________________________
# ___________________________________________________________________________________
#
#
#
# sample_id 	 p3p3661_248902
# timestamp 	 2014-08-05T11:28:00Z
#
#
# username 	 178.194.81.42
# 	 	 >>> NON registered user
#
# comment 	 /* Un monument en constante transformation */
#
# title    	 Château de Pierrefonds
# link      	 https://fr.wikipedia.org/w/index.php?diff=106009920&oldid=105780947
#
#
#
#
# ___________________________________________________________________________________
# ___________________________________Remaining items: 97___________________________________
# ___________________________________________________________________________________
#
#
#
# sample_id 	 p3p3661_931556
# timestamp 	 2007-06-12T16:03:04Z
#
#
# username 	 Zedh
# 	 	 >>> registered user
# comment 	 /* Catégorie 5e */ corr baclée (je repasserai)
#
# title    	 Paire torsadée
# link      	 https://fr.wikipedia.org/w/index.php?diff=17836113&oldid=17807973
#
#
#
#
# ___________________________________________________________________________________
# ___________________________________Remaining items: 96___________________________________
# ___________________________________________________________________________________
#
#
#
# sample_id 	 p3p3661_494479
# timestamp 	 2017-03-17T18:57:49Z
#
#
# username 	 Authueil
# 	 	 >>> registered user
# comment 	 Annulation de la [[Spécial:Diff/135511330|modification]] de [[Spécial:Contributions/2A01:E34:EF91:E620:5838:3F:F214:B331|2A01:E34:EF91:E620:5838:3F:F214:B331]] ([[User talk:2A01:E34:EF91:E620:5838:3F:F214:B331|d]])
#
# title    	 Guinée
# link      	 https://fr.wikipedia.org/w/index.php?diff=135511369&oldid=135511330
#
#
#
#
# ___________________________________________________________________________________
# ___________________________________Remaining items: 95___________________________________
# ___________________________________________________________________________________
#
#
#
# sample_id 	 p3p3661_369947
# timestamp 	 2010-04-26T21:14:36Z
#
#
# username 	 Fuucx
# 	 	 >>> registered user
# comment 	 /* Euro et liberté de la politique monétaire */ nettoyage non soucé à reformuler
#
# title    	 Euro
# link      	 https://fr.wikipedia.org/w/index.php?diff=52645074&oldid=52597404
#
#
#
#
# ___________________________________________________________________________________
# ___________________________________Remaining items: 94___________________________________
# ___________________________________________________________________________________
#
#
#
# sample_id 	 p3p3661_1166851
# timestamp 	 2008-01-23T21:40:31Z
#
#
# username 	 Kurgbe
# 	 	 >>> registered user
# comment 	 /* {{BE-NL}} */
#
# title    	 Télévision numérique terrestre
# link      	 https://fr.wikipedia.org/w/index.php?diff=25303319&oldid=25303147
#
#
#
#
# ___________________________________________________________________________________
# ___________________________________Remaining items: 93___________________________________
# ___________________________________________________________________________________
#
#
#
# sample_id 	 p3p3661_859786
# timestamp 	 2009-06-24T18:32:34Z
#
#
# username 	 Fuucx
# 	 	 >>> registered user
# comment 	 /* Comment réguler l’économie ? */ style
#
# title    	 New Deal
# link      	 https://fr.wikipedia.org/w/index.php?diff=42346634&oldid=42346267
#
#
#
#
# ___________________________________________________________________________________
# ___________________________________Remaining items: 92___________________________________
# ___________________________________________________________________________________
#
#
#
# sample_id 	 p3p3661_436582
# timestamp 	 2014-10-12T20:50:21Z
#
#
# username 	 83.155.87.102
# 	 	 >>> NON registered user
#
# comment 	 Valérie plane beaucoup dernierement
#
# title    	 Formule développée plane
# link      	 https://fr.wikipedia.org/w/index.php?diff=108178071&oldid=108177665
#
#
#
#
# ___________________________________________________________________________________
# ___________________________________Remaining items: 91___________________________________
# ___________________________________________________________________________________
#
#
#
# sample_id 	 p3p3661_138616
# timestamp 	 2004-08-10T20:00:33Z
#
#
# username 	 217.233.13.90
# 	 	 >>> NON registered user
#
# comment
#
# title    	 Bas-Rhin
# link      	 https://fr.wikipedia.org/w/index.php?diff=716694&oldid=694962
#
#
#
#
# ___________________________________________________________________________________
# ___________________________________Remaining items: 90___________________________________
# ___________________________________________________________________________________
#
#
#
# sample_id 	 p3662p10075_959918
# timestamp 	 2013-06-27T20:00:31Z
#
#
# username 	 PitiNasri
# 	 	 >>> registered user
# comment
#
# title    	 Chapeau melon et bottes de cuir
# link      	 https://fr.wikipedia.org/w/index.php?diff=94485758&oldid=94345461
#
#
#
#
# ___________________________________________________________________________________
# ___________________________________Remaining items: 89___________________________________
# ___________________________________________________________________________________
#
#
#
# sample_id 	 p3662p10075_876788
# timestamp 	 2012-12-02T18:26:01Z
#
#
# username 	 Jorge de Burgos
# 	 	 >>> registered user
# comment 	 /* Géographie physique */
#
# title    	 Massachusetts
# link      	 https://fr.wikipedia.org/w/index.php?diff=86030995&oldid=86030807
#
#
#
#
# ___________________________________________________________________________________
# ___________________________________Remaining items: 88___________________________________
# ___________________________________________________________________________________
#
#
#
# sample_id 	 p3662p10075_732991
# timestamp 	 2010-01-22T11:48:22Z
#
#
# username 	 Colporteur
# 	 	 >>> registered user
# comment 	 /* Analyse */
#
# title    	 Le Capitaine Fracasse
# link      	 https://fr.wikipedia.org/w/index.php?diff=49105376&oldid=49105363
#
#
#
#
# ___________________________________________________________________________________
# ___________________________________Remaining items: 87___________________________________
# ___________________________________________________________________________________
#
#
#
# sample_id 	 p3662p10075_860045
# timestamp 	 2010-08-02T08:13:58Z
#
#
# username 	 80.8.190.168
# 	 	 >>> NON registered user
#
# comment 	 .
#
# title    	 La Réunion
# link      	 https://fr.wikipedia.org/w/index.php?diff=55772305&oldid=55771962
#
#
#
#
# ___________________________________________________________________________________
# ___________________________________Remaining items: 86___________________________________
# ___________________________________________________________________________________
#
#
#
# sample_id 	 p3662p10075_1276063
# timestamp 	 2007-03-12T06:46:05Z
#
#
# username 	 Manchot
# 	 	 >>> registered user
# comment 	 /* Transport routier */ +ref
#
# title    	 La Rochelle
# link      	 https://fr.wikipedia.org/w/index.php?diff=14980313&oldid=14980236
#
#
#
#
# ___________________________________________________________________________________
# ___________________________________Remaining items: 85___________________________________
# ___________________________________________________________________________________
#
#
#
# sample_id 	 p3662p10075_755278
# timestamp 	 2016-06-16T20:01:20Z
#
#
# username 	 Gael de Sailly
# 	 	 >>> registered user
# comment 	 Coquille
#
# title    	 Étienne de La Boétie
# link      	 https://fr.wikipedia.org/w/index.php?diff=127116397&oldid=127103744
#
#
#
#
# ___________________________________________________________________________________
# ___________________________________Remaining items: 84___________________________________
# ___________________________________________________________________________________
#
#
#
# sample_id 	 p3662p10075_860649
# timestamp 	 2013-05-24T12:12:25Z
#
#
# username 	 79.141.207.101
# 	 	 >>> NON registered user
#
# comment 	 /* Flore */
#
# title    	 La Réunion
# link      	 https://fr.wikipedia.org/w/index.php?diff=93416478&oldid=93385867
#
#
#
#
# ___________________________________________________________________________________
# ___________________________________Remaining items: 83___________________________________
# ___________________________________________________________________________________
#
#
#
# sample_id 	 p3662p10075_203439
# timestamp 	 2012-11-28T14:59:16Z
#
#
# username 	 Tourissimement
# 	 	 >>> registered user
# comment 	 /* Glamping */
#
# title    	 Écotourisme
# link      	 https://fr.wikipedia.org/w/index.php?diff=85862411&oldid=85862362
#
#
#
#
# ___________________________________________________________________________________
# ___________________________________Remaining items: 82___________________________________
# ___________________________________________________________________________________
#
#
#
# sample_id 	 p3662p10075_721765
# timestamp 	 2009-07-07T17:15:31Z
#
#
# username 	 132.203.70.17
# 	 	 >>> NON registered user
#
# comment
#
# title    	 Tartiflette
# link      	 https://fr.wikipedia.org/w/index.php?diff=42764680&oldid=38629669
#
#
#
#
# ___________________________________________________________________________________
# ___________________________________Remaining items: 81___________________________________
# ___________________________________________________________________________________
#
#
#
# sample_id 	 p3662p10075_826320
# timestamp 	 2008-12-30T10:10:20Z
#
#
# username 	 81.49.37.206
# 	 	 >>> NON registered user
#
# comment 	 /* Commandes et environnements */
#
# title    	 Aide:Formules TeX
# link      	 https://fr.wikipedia.org/w/index.php?diff=36567401&oldid=36325078
#
#
#
#
# ___________________________________________________________________________________
# ___________________________________Remaining items: 80___________________________________
# ___________________________________________________________________________________
#
#
#
# sample_id 	 p10076p18526_843530
# timestamp 	 2007-05-13T09:00:34Z
#
#
# username 	 85.26.0.158
# 	 	 >>> NON registered user
#
# comment 	 /* La période française */
#
# title    	 Histoire de la Belgique
# link      	 https://fr.wikipedia.org/w/index.php?diff=16799766&oldid=16784657
#
#
#
#
# ___________________________________________________________________________________
# ___________________________________Remaining items: 79___________________________________
# ___________________________________________________________________________________
#
#
#
# sample_id 	 p10076p18526_55869
# timestamp 	 2008-09-08T05:37:08Z
#
#
# username 	 Égoïté
# 	 	 >>> registered user
# comment 	 /* Transport inter-urbain */
#
# title    	 Cherbourg-Octeville
# link      	 https://fr.wikipedia.org/w/index.php?diff=33219105&oldid=33219096
#
#
#
#
# ___________________________________________________________________________________
# ___________________________________Remaining items: 78___________________________________
# ___________________________________________________________________________________
#
#
#
# sample_id 	 p10076p18526_567916
# timestamp 	 2007-01-27T03:20:27Z
#
#
# username 	 82.244.25.138
# 	 	 >>> NON registered user
#
# comment 	 /* Cinéma et télévision */
#
# title    	 Boston
# link      	 https://fr.wikipedia.org/w/index.php?diff=13636899&oldid=13304809
#
#
#
#
# ___________________________________________________________________________________
# ___________________________________Remaining items: 77___________________________________
# ___________________________________________________________________________________
#
#
#
# sample_id 	 p10076p18526_354987
# timestamp 	 2017-02-08T17:25:24Z
#
#
# username 	 Harvey Stillnot
# 	 	 >>> registered user
# comment 	 /* Zinc métal réducteur */ fin
#
# title    	 Zinc
# link      	 https://fr.wikipedia.org/w/index.php?diff=134374943&oldid=134374533
#
#
#
#
# ___________________________________________________________________________________
# ___________________________________Remaining items: 76___________________________________
# ___________________________________________________________________________________
#
#
#
# sample_id 	 p10076p18526_771299
# timestamp 	 2007-12-08T14:57:54Z
#
#
# username 	 212.194.162.88
# 	 	 >>> NON registered user
#
# comment
#
# title    	 TF1
# link      	 https://fr.wikipedia.org/w/index.php?diff=23778720&oldid=23694353
#
#
#
#
# ___________________________________________________________________________________
# ___________________________________Remaining items: 75___________________________________
# ___________________________________________________________________________________
#
#
#
# sample_id 	 p10076p18526_17979
# timestamp 	 2015-10-18T09:37:30Z
#
#
# username 	 Albergrin007
# 	 	 >>> registered user
# comment 	 /* Polémiques autour de l'expression « race blanche » */
#
# title    	 Nadine Morano
# link      	 https://fr.wikipedia.org/w/index.php?diff=119590136&oldid=119589884
#
#
#
#
# ___________________________________________________________________________________
# ___________________________________Remaining items: 74___________________________________
# ___________________________________________________________________________________
#
#
#
# sample_id 	 p10076p18526_1314639
# timestamp 	 2015-03-09T00:17:54Z
#
#
# username 	 197.118.33.70
# 	 	 >>> NON registered user
#
# comment
#
# title    	 Éclipse
# link      	 https://fr.wikipedia.org/w/index.php?diff=112585270&oldid=112372407
#
#
#
#
# ___________________________________________________________________________________
# ___________________________________Remaining items: 73___________________________________
# ___________________________________________________________________________________
#
#
#
# sample_id 	 p10076p18526_1286210
# timestamp 	 2009-03-19T21:02:17Z
#
#
# username 	 81.249.80.226
# 	 	 >>> NON registered user
#
# comment
#
# title    	 Autriche-Hongrie
# link      	 https://fr.wikipedia.org/w/index.php?diff=39113884&oldid=39113429
#
#
#
#
# ___________________________________________________________________________________
# ___________________________________Remaining items: 72___________________________________
# ___________________________________________________________________________________
#
#
#
# sample_id 	 p10076p18526_1295030
# timestamp 	 2016-10-04T20:18:42Z
#
#
# username 	 Chaumot
# 	 	 >>> registered user
# comment 	 /* Biographie */
#
# title    	 Gustave Caillebotte
# link      	 https://fr.wikipedia.org/w/index.php?diff=130362762&oldid=130362385
#
#
#
#
# ___________________________________________________________________________________
# ___________________________________Remaining items: 71___________________________________
# ___________________________________________________________________________________
#
#
#
# sample_id 	 p10076p18526_3171
# timestamp 	 2005-09-01T17:23:45Z
#
#
# username 	 Yelkrokoyade
# 	 	 >>> registered user
# comment 	 + outils
#
# title    	 Jardinage
# link      	 https://fr.wikipedia.org/w/index.php?diff=3213330&oldid=3192344
#
#
#
#
# ___________________________________________________________________________________
# ___________________________________Remaining items: 70___________________________________
# ___________________________________________________________________________________
#
#
#
# sample_id 	 p18527p30361_7310
# timestamp 	 2008-10-11T00:33:35Z
#
#
# username 	 Great11
# 	 	 >>> registered user
# comment 	 /* Les conflits Berbères */
#
# title    	 Berbères
# link      	 https://fr.wikipedia.org/w/index.php?diff=34235667&oldid=34230109
#
#
#
#
# ___________________________________________________________________________________
# ___________________________________Remaining items: 69___________________________________
# ___________________________________________________________________________________
#
#
#
# sample_id 	 p18527p30361_670871
# timestamp 	 2003-08-30T15:41:00Z
#
#
# username 	 62.39.174.45
# 	 	 >>> NON registered user
#
# comment 	 sommaire. Wikification.
#
# title    	 Accordéon
# link      	 https://fr.wikipedia.org/w/index.php?diff=129691&oldid=107348
#
#
#
#
# ___________________________________________________________________________________
# ___________________________________Remaining items: 68___________________________________
# ___________________________________________________________________________________
#
#
#
# sample_id 	 p18527p30361_1134839
# timestamp 	 2009-09-05T16:10:52Z
#
#
# username 	 Cerhab
# 	 	 >>> registered user
# comment
#
# title    	 Rétine
# link      	 https://fr.wikipedia.org/w/index.php?diff=44545371&oldid=44516086
#
#
#
#
# ___________________________________________________________________________________
# ___________________________________Remaining items: 67___________________________________
# ___________________________________________________________________________________
#
#
#
# sample_id 	 p18527p30361_498519
# timestamp 	 2007-11-04T08:35:04Z
#
#
# username 	 Lacuzon
# 	 	 >>> registered user
# comment
#
# title    	 Vesoul
# link      	 https://fr.wikipedia.org/w/index.php?diff=22532503&oldid=22339148
#
#
#
#
# ___________________________________________________________________________________
# ___________________________________Remaining items: 66___________________________________
# ___________________________________________________________________________________
#
#
#
# sample_id 	 p18527p30361_1483832
# timestamp 	 2010-03-21T21:05:57Z
#
#
# username 	 Monsieur Fou
# 	 	 >>> registered user
# comment
#
# title    	 Unité urbaine
# link      	 https://fr.wikipedia.org/w/index.php?diff=51393483&oldid=51392364
#
#
#
#
# ___________________________________________________________________________________
# ___________________________________Remaining items: 65___________________________________
# ___________________________________________________________________________________
#
#
#
# sample_id 	 p18527p30361_668879
# timestamp 	 2011-06-30T02:00:10Z
#
#
# username 	 Skull33
# 	 	 >>> registered user
# comment 	 [[WP:LRC|LiveRC]] : Révocation des modifications de [[Special:Contributions/93.24.179.170|93.24.179.170]] (retour à la dernière version de [[User:Mr. Frank|Mr. Frank]]) ; nous ne sommes pas là pour en juger
#
# title    	 John Lennon
# link      	 https://fr.wikipedia.org/w/index.php?diff=66953185&oldid=66953140
#
#
#
#
# ___________________________________________________________________________________
# ___________________________________Remaining items: 64___________________________________
# ___________________________________________________________________________________
#
#
#
# sample_id 	 p18527p30361_48776
# timestamp 	 2017-03-16T18:31:03Z
#
#
# username 	 Tim9
# 	 	 >>> registered user
# comment 	 /* Accès et transports */
#
# title    	 Lillers
# link      	 https://fr.wikipedia.org/w/index.php?diff=135480800&oldid=135278081
#
#
#
#
# ___________________________________________________________________________________
# ___________________________________Remaining items: 63___________________________________
# ___________________________________________________________________________________
#
#
#
# sample_id 	 p18527p30361_622879
# timestamp 	 2008-06-19T09:09:10Z
#
#
# username 	 213.215.35.3
# 	 	 >>> NON registered user
#
# comment 	 /* Relation avec les femmes */
#
# title    	 Charlie Chaplin
# link      	 https://fr.wikipedia.org/w/index.php?diff=30781704&oldid=30634724
#
#
#
#
# ___________________________________________________________________________________
# ___________________________________Remaining items: 62___________________________________
# ___________________________________________________________________________________
#
#
#
# sample_id 	 p18527p30361_784728
# timestamp 	 2011-03-16T15:16:16Z
#
#
# username 	 LPLT
# 	 	 >>> registered user
# comment 	 /* Albums et concerts */ précision
#
# title    	 Bertrand Cantat
# link      	 https://fr.wikipedia.org/w/index.php?diff=63252442&oldid=63251355
#
#
#
#
# ___________________________________________________________________________________
# ___________________________________Remaining items: 61___________________________________
# ___________________________________________________________________________________
#
#
#
# sample_id 	 p18527p30361_351908
# timestamp 	 2008-12-18T19:29:16Z
#
#
# username 	 88.175.2.90
# 	 	 >>> NON registered user
#
# comment
#
# title    	 Planeur
# link      	 https://fr.wikipedia.org/w/index.php?diff=36255931&oldid=36145807
#
#
#
#
# ___________________________________________________________________________________
# ___________________________________Remaining items: 60___________________________________
# ___________________________________________________________________________________
#
#
#
# sample_id 	 p30362p43904_243603
# timestamp 	 2011-01-14T15:27:12Z
#
#
# username 	 Kzo
# 	 	 >>> registered user
# comment
#
# title    	 Sant Julià de Lòria
# link      	 https://fr.wikipedia.org/w/index.php?diff=61272171&oldid=60665097
#
#
#
#
# ___________________________________________________________________________________
# ___________________________________Remaining items: 59___________________________________
# ___________________________________________________________________________________
#
#
#
# sample_id 	 p30362p43904_1057335
# timestamp 	 2010-05-27T06:28:48Z
#
#
# username 	 Jean.claude
# 	 	 >>> registered user
# comment
#
# title    	 Céphalanthère à feuilles étroites
# link      	 https://fr.wikipedia.org/w/index.php?diff=53674819&oldid=53674801
#
#
#
#
# ___________________________________________________________________________________
# ___________________________________Remaining items: 58___________________________________
# ___________________________________________________________________________________
#
#
#
# sample_id 	 p30362p43904_921339
# timestamp 	 2012-07-25T00:46:24Z
#
#
# username 	 92.132.230.16
# 	 	 >>> NON registered user
#
# comment
#
# title    	 Germanie
# link      	 https://fr.wikipedia.org/w/index.php?diff=81219022&oldid=80463406
#
#
#
#
# ___________________________________________________________________________________
# ___________________________________Remaining items: 57___________________________________
# ___________________________________________________________________________________
#
#
#
# sample_id 	 p30362p43904_1319709
# timestamp 	 2009-08-26T13:55:15Z
#
#
# username 	 158.169.131.14
# 	 	 >>> NON registered user
#
# comment 	 /* Histoire */
#
# title    	 Péninsule Ibérique
# link      	 https://fr.wikipedia.org/w/index.php?diff=44220497&oldid=44220446
#
#
#
#
# ___________________________________________________________________________________
# ___________________________________Remaining items: 56___________________________________
# ___________________________________________________________________________________
#
#
#
# sample_id 	 p30362p43904_1173190
# timestamp 	 2016-08-28T17:08:09Z
#
#
# username 	 Samish de normandie
# 	 	 >>> registered user
# comment 	 Ajout d'une virgule
#
# title    	 Anjou
# link      	 https://fr.wikipedia.org/w/index.php?diff=129065348&oldid=128747283
#
#
#
#
# ___________________________________________________________________________________
# ___________________________________Remaining items: 55___________________________________
# ___________________________________________________________________________________
#
#
#
# sample_id 	 p30362p43904_673106
# timestamp 	 2007-05-17T07:57:09Z
#
#
# username 	 82.226.53.164
# 	 	 >>> NON registered user
#
# comment 	 /* Géographie */
#
# title    	 Schirmeck
# link      	 https://fr.wikipedia.org/w/index.php?diff=16944965&oldid=16930883
#
#
#
#
# ___________________________________________________________________________________
# ___________________________________Remaining items: 54___________________________________
# ___________________________________________________________________________________
#
#
#
# sample_id 	 p30362p43904_1502006
# timestamp 	 2015-10-30T18:21:08Z
#
#
# username 	 Mentos92
# 	 	 >>> registered user
# comment 	 /* Confirmation critique et commerciale (2000-2007) */
#
# title    	 Virginie Ledoyen
# link      	 https://fr.wikipedia.org/w/index.php?diff=120014923&oldid=120014901
#
#
#
#
# ___________________________________________________________________________________
# ___________________________________Remaining items: 53___________________________________
# ___________________________________________________________________________________
#
#
#
# sample_id 	 p30362p43904_148113
# timestamp 	 2011-12-14T00:53:48Z
#
#
# username 	 Gaeth972
# 	 	 >>> registered user
# comment 	 /* Touristiques et Affaires */
#
# title    	 Fort-de-France
# link      	 https://fr.wikipedia.org/w/index.php?diff=73125826&oldid=73125810
#
#
#
#
# ___________________________________________________________________________________
# ___________________________________Remaining items: 52___________________________________
# ___________________________________________________________________________________
#
#
#
# sample_id 	 p30362p43904_556366
# timestamp 	 2017-01-29T11:54:10Z
#
#
# username 	 Ruyblas13
# 	 	 >>> registered user
# comment 	 /* Absolutisme */ références d'appui et complément.
#
# title    	 Charles V le Sage
# link      	 https://fr.wikipedia.org/w/index.php?diff=134075036&oldid=134074210
#
#
#
#
# ___________________________________________________________________________________
# ___________________________________Remaining items: 51___________________________________
# ___________________________________________________________________________________
#
#
#
# sample_id 	 p30362p43904_1471820
# timestamp 	 2007-10-15T13:22:00Z
#
#
# username 	 86.216.119.239
# 	 	 >>> NON registered user
#
# comment 	 /* Origine */
#
# title    	 Gilbert du Motier de La Fayette
# link      	 https://fr.wikipedia.org/w/index.php?diff=21778962&oldid=21778945
#
#
#
#
# ___________________________________________________________________________________
# ___________________________________Remaining items: 50___________________________________
# ___________________________________________________________________________________
#
#
#
# sample_id 	 p43905p56252_285454
# timestamp 	 2006-03-29T10:15:23Z
#
#
# username 	 86.198.190.110
# 	 	 >>> NON registered user
#
# comment 	 /* Témoignages sur le milieu du X */
#
# title    	 Film pornographique
# link      	 https://fr.wikipedia.org/w/index.php?diff=6347912&oldid=6347882
#
#
#
#
# ___________________________________________________________________________________
# ___________________________________Remaining items: 49___________________________________
# ___________________________________________________________________________________
#
#
#
# sample_id 	 p43905p56252_869504
# timestamp 	 2010-07-30T22:30:46Z
#
#
# username 	 90.48.237.221
# 	 	 >>> NON registered user
#
# comment
#
# title    	 Elne
# link      	 https://fr.wikipedia.org/w/index.php?diff=55706864&oldid=55706669
#
#
#
#
# ___________________________________________________________________________________
# ___________________________________Remaining items: 48___________________________________
# ___________________________________________________________________________________
#
#
#
# sample_id 	 p43905p56252_829635
# timestamp 	 2008-08-18T21:33:57Z
#
#
# username 	 Gdgourou
# 	 	 >>> registered user
# comment 	 suite
#
# title    	 Mickey Mouse
# link      	 https://fr.wikipedia.org/w/index.php?diff=32549218&oldid=32547974
#
#
#
#
# ___________________________________________________________________________________
# ___________________________________Remaining items: 47___________________________________
# ___________________________________________________________________________________
#
#
#
# sample_id 	 p43905p56252_872271
# timestamp 	 2017-07-07T13:59:19Z
#
#
# username 	 128.141.223.121
# 	 	 >>> NON registered user
#
# comment 	 Les informations sur les formations et la vie de l'école n'avaient pas été mises à jour depuis longtemps (certaines formations n'étaient pas référencées)
#
# title    	 Télécom physique Strasbourg
# link      	 https://fr.wikipedia.org/w/index.php?diff=138768511&oldid=137479271
#
#
#
#
# ___________________________________________________________________________________
# ___________________________________Remaining items: 46___________________________________
# ___________________________________________________________________________________
#
#
#
# sample_id 	 p43905p56252_380885
# timestamp 	 2014-12-17T14:33:43Z
#
#
# username 	 Priper
# 	 	 >>> registered user
# comment 	 /* Polygamie en Belgique */
#
# title    	 Polygamie
# link      	 https://fr.wikipedia.org/w/index.php?diff=110032068&oldid=108213862
#
#
#
#
# ___________________________________________________________________________________
# ___________________________________Remaining items: 45___________________________________
# ___________________________________________________________________________________
#
#
#
# sample_id 	 p43905p56252_291559
# timestamp 	 2014-12-12T18:20:40Z
#
#
# username 	 206.167.17.71
# 	 	 >>> NON registered user
#
# comment 	 La section Découverte de la conduction électrique par Gray
#
# title    	 Ligne à haute tension
# link      	 https://fr.wikipedia.org/w/index.php?diff=109895863&oldid=109303515
#
#
#
#
# ___________________________________________________________________________________
# ___________________________________Remaining items: 44___________________________________
# ___________________________________________________________________________________
#
#
#
# sample_id 	 p43905p56252_874028
# timestamp 	 2008-12-01T17:44:06Z
#
#
# username 	 Maurilbert
# 	 	 >>> registered user
# comment 	 [[User:EDUCA33E/LiveRC/Documentation|LiveRC]] : Révocation des modifications de [[Special:Contributions/204.174.129.59|204.174.129.59]]; retour à la version de [[User:Alecs.bot|Alecs.bot]]
#
# title    	 Kinshasa
# link      	 https://fr.wikipedia.org/w/index.php?diff=35762242&oldid=35762174
#
#
#
#
# ___________________________________________________________________________________
# ___________________________________Remaining items: 43___________________________________
# ___________________________________________________________________________________
#
#
#
# sample_id 	 p43905p56252_973228
# timestamp 	 2009-08-07T10:33:33Z
#
#
# username 	 195.220.252.125
# 	 	 >>> NON registered user
#
# comment 	 /* Apparitions */
#
# title    	 Fairchild A-10 Thunderbolt II
# link      	 https://fr.wikipedia.org/w/index.php?diff=43634353&oldid=43594548
#
#
#
#
# ___________________________________________________________________________________
# ___________________________________Remaining items: 42___________________________________
# ___________________________________________________________________________________
#
#
#
# sample_id 	 p43905p56252_585972
# timestamp 	 2014-12-11T23:26:25Z
#
#
# username 	 AviaWiki
# 	 	 >>> registered user
# comment 	 /* Travail de conception */ wikif
#
# title    	 Boeing B-52 Stratofortress
# link      	 https://fr.wikipedia.org/w/index.php?diff=109877340&oldid=109877323
#
#
#
#
# ___________________________________________________________________________________
# ___________________________________Remaining items: 41___________________________________
# ___________________________________________________________________________________
#
#
#
# sample_id 	 p43905p56252_1498911
# timestamp 	 2010-03-16T22:01:06Z
#
#
# username 	 Pradigue
# 	 	 >>> registered user
# comment 	 /* Première Guerre punique : choc frontal avec Rome */
#
# title    	 Histoire de Carthage
# link      	 https://fr.wikipedia.org/w/index.php?diff=51209890&oldid=51209548
#
#
#
#
# ___________________________________________________________________________________
# ___________________________________Remaining items: 40___________________________________
# ___________________________________________________________________________________
#
#
#
# sample_id 	 p56253p71552_1110000
# timestamp 	 2017-07-11T11:06:30Z
#
#
# username 	 Tadeucsz
# 	 	 >>> registered user
# comment 	 /* Fait marquant */
#
# title    	 Festival de Cannes 1979
# link      	 https://fr.wikipedia.org/w/index.php?diff=138864510&oldid=138864466
#
#
#
#
# ___________________________________________________________________________________
# ___________________________________Remaining items: 39___________________________________
# ___________________________________________________________________________________
#
#
#
# sample_id 	 p56253p71552_751961
# timestamp 	 2007-04-17T11:43:52Z
#
#
# username 	 82.127.92.21
# 	 	 >>> NON registered user
#
# comment 	 /* Quelques autres œuvres de Raphaël */
#
# title    	 Raphaël (peintre)
# link      	 https://fr.wikipedia.org/w/index.php?diff=15991507&oldid=15932229
#
#
#
#
# ___________________________________________________________________________________
# ___________________________________Remaining items: 38___________________________________
# ___________________________________________________________________________________
#
#
#
# sample_id 	 p56253p71552_498475
# timestamp 	 2005-04-22T21:52:10Z
#
#
# username 	 Accrochoc
# 	 	 >>> registered user
# comment 	 résultat de l'élection partiellle
#
# title    	 Canton de Gentioux-Pigerolles
# link      	 https://fr.wikipedia.org/w/index.php?diff=2384183&oldid=1850205
#
#
#
#
# ___________________________________________________________________________________
# ___________________________________Remaining items: 37___________________________________
# ___________________________________________________________________________________
#
#
#
# sample_id 	 p56253p71552_599061
# timestamp 	 2013-01-17T20:21:18Z
#
#
# username 	 109.24.194.19
# 	 	 >>> NON registered user
#
# comment
#
# title    	 Obligation (finance)
# link      	 https://fr.wikipedia.org/w/index.php?diff=87751576&oldid=87751559
#
#
#
#
# ___________________________________________________________________________________
# ___________________________________Remaining items: 36___________________________________
# ___________________________________________________________________________________
#
#
#
# sample_id 	 p56253p71552_884745
# timestamp 	 2013-08-30T12:48:59Z
#
#
# username 	 93.1.139.139
# 	 	 >>> NON registered user
#
# comment 	 /* Sports */
#
# title    	 Gap
# link      	 https://fr.wikipedia.org/w/index.php?diff=96258764&oldid=96232434
#
#
#
#
# ___________________________________________________________________________________
# ___________________________________Remaining items: 35___________________________________
# ___________________________________________________________________________________
#
#
#
# sample_id 	 p56253p71552_212557
# timestamp 	 2017-05-23T17:03:19Z
#
#
# username 	 Sidonie61
# 	 	 >>> registered user
# comment 	 /* Premiers pas vers le métier d'infirmière */ WP ne constitue pas une référence
#
# title    	 Florence Nightingale
# link      	 https://fr.wikipedia.org/w/index.php?diff=137598128&oldid=137597972
#
#
#
#
# ___________________________________________________________________________________
# ___________________________________Remaining items: 34___________________________________
# ___________________________________________________________________________________
#
#
#
# sample_id 	 p56253p71552_990424
# timestamp 	 2009-11-13T12:20:23Z
#
#
# username 	 Roymail
# 	 	 >>> registered user
# comment
#
# title    	 Cappadoce
# link      	 https://fr.wikipedia.org/w/index.php?diff=46755586&oldid=46755104
#
#
#
#
# ___________________________________________________________________________________
# ___________________________________Remaining items: 33___________________________________
# ___________________________________________________________________________________
#
#
#
# sample_id 	 p56253p71552_848258
# timestamp 	 2008-10-26T18:01:38Z
#
#
# username 	 Molinensis
# 	 	 >>> registered user
# comment 	 /* Les liturgies chrétiennes */ Précision
#
# title    	 Liturgie
# link      	 https://fr.wikipedia.org/w/index.php?diff=34695813&oldid=34414597
#
#
#
#
# ___________________________________________________________________________________
# ___________________________________Remaining items: 32___________________________________
# ___________________________________________________________________________________
#
#
#
# sample_id 	 p56253p71552_1135652
# timestamp 	 2013-04-22T09:54:12Z
#
#
# username 	 Françoise Maîtresse
# 	 	 >>> registered user
# comment 	 /* Incidence de la pratique */
#
# title    	 Fist-fucking
# link      	 https://fr.wikipedia.org/w/index.php?diff=92347851&oldid=92347817
#
#
#
#
# ___________________________________________________________________________________
# ___________________________________Remaining items: 31___________________________________
# ___________________________________________________________________________________
#
#
#
# sample_id 	 p56253p71552_141210
# timestamp 	 2008-09-25T17:24:05Z
#
#
# username 	 Alphabeta
# 	 	 >>> registered user
# comment 	  l’[[ordre de la Jarretière]] et l’[[ordre du Chardon]]
#
# title    	 Baronnet
# link      	 https://fr.wikipedia.org/w/index.php?diff=33761067&oldid=32668523
#
#
#
#
# ___________________________________________________________________________________
# ___________________________________Remaining items: 30___________________________________
# ___________________________________________________________________________________
#
#
#
# sample_id 	 p71553p89754_405858
# timestamp 	 2004-06-05T23:04:57Z
#
#
# username 	 Bakasama
# 	 	 >>> registered user
# comment 	 +spirou
#
# title    	 Jean-Michel Thiriet
# link      	 https://fr.wikipedia.org/w/index.php?diff=597113&oldid=510673
#
#
#
#
# ___________________________________________________________________________________
# ___________________________________Remaining items: 29___________________________________
# ___________________________________________________________________________________
#
#
#
# sample_id 	 p71553p89754_1387958
# timestamp 	 2012-12-03T14:26:00Z
#
#
# username 	 82.23.146.41
# 	 	 >>> NON registered user
#
# comment 	 /* Le pacte autobiographique */
#
# title    	 Les Confessions (Rousseau)
# link      	 https://fr.wikipedia.org/w/index.php?diff=86069989&oldid=86069899
#
#
#
#
# ___________________________________________________________________________________
# ___________________________________Remaining items: 28___________________________________
# ___________________________________________________________________________________
#
#
#
# sample_id 	 p71553p89754_241596
# timestamp 	 2015-02-09T22:19:08Z
#
#
# username 	 81.66.247.78
# 	 	 >>> NON registered user
#
# comment 	 /* Accueil public et critique */ Mise à jour Chassement IMDb
#
# title    	 Vol au-dessus d'un nid de coucou
# link      	 https://fr.wikipedia.org/w/index.php?diff=111709661&oldid=111301306
#
#
#
#
# ___________________________________________________________________________________
# ___________________________________Remaining items: 27___________________________________
# ___________________________________________________________________________________
#
#
#
# sample_id 	 p71553p89754_1117907
# timestamp 	 2007-10-11T19:29:42Z
#
#
# username 	 Olnu
# 	 	 >>> registered user
# comment 	 /* Belgique */
#
# title    	 Francophobie
# link      	 https://fr.wikipedia.org/w/index.php?diff=21666533&oldid=21665702
#
#
#
#
# ___________________________________________________________________________________
# ___________________________________Remaining items: 26___________________________________
# ___________________________________________________________________________________
#
#
#
# sample_id 	 p71553p89754_735960
# timestamp 	 2010-01-11T09:47:15Z
#
#
# username 	 Frór
# 	 	 >>> registered user
# comment 	 /* Vie personnelle */ Information inutile dans une encyclopédie.
#
# title    	 Kim Clijsters
# link      	 https://fr.wikipedia.org/w/index.php?diff=48697217&oldid=48696204
#
#
#
#
# ___________________________________________________________________________________
# ___________________________________Remaining items: 25___________________________________
# ___________________________________________________________________________________
#
#
#
# sample_id 	 p71553p89754_1347853
# timestamp 	 2009-12-02T09:10:03Z
#
#
# username 	 144.204.16.1
# 	 	 >>> NON registered user
#
# comment 	 /* Enfance et éducation */
#
# title    	 Philippe d'Orléans (1640-1701)
# link      	 https://fr.wikipedia.org/w/index.php?diff=47340496&oldid=46399626
#
#
#
#
# ___________________________________________________________________________________
# ___________________________________Remaining items: 24___________________________________
# ___________________________________________________________________________________
#
#
#
# sample_id 	 p71553p89754_1363935
# timestamp 	 2014-02-15T08:46:59Z
#
#
# username 	 Patho~frwiki
# 	 	 >>> registered user
# comment
#
# title    	 Anatomo-pathologie
# link      	 https://fr.wikipedia.org/w/index.php?diff=101264829&oldid=100189364
#
#
#
#
# ___________________________________________________________________________________
# ___________________________________Remaining items: 23___________________________________
# ___________________________________________________________________________________
#
#
#
# sample_id 	 p71553p89754_1228665
# timestamp 	 2014-08-08T19:29:45Z
#
#
# username 	 123.20.45.99
# 	 	 >>> NON registered user
#
# comment 	 ajout d'information complémentaire importante.
#
# title    	 Baie de Hạ Long
# link      	 https://fr.wikipedia.org/w/index.php?diff=106105892&oldid=106068084
#
#
#
#
# ___________________________________________________________________________________
# ___________________________________Remaining items: 22___________________________________
# ___________________________________________________________________________________
#
#
#
# sample_id 	 p71553p89754_546343
# timestamp 	 2012-01-18T20:42:37Z
#
#
# username 	 Rolmarec
# 	 	 >>> registered user
# comment 	 Sapphô n'est pas à Mytiléne mais Erésos
#
# title    	 Alcée de Mytilène
# link      	 https://fr.wikipedia.org/w/index.php?diff=74510327&oldid=74110032
#
#
#
#
# ___________________________________________________________________________________
# ___________________________________Remaining items: 21___________________________________
# ___________________________________________________________________________________
#
#
#
# sample_id 	 p71553p89754_615934
# timestamp 	 2017-01-01T12:48:38Z
#
#
# username 	 Hypsibius
# 	 	 >>> registered user
# comment 	 images historiques
#
# title    	 Lycée Henri-IV
# link      	 https://fr.wikipedia.org/w/index.php?diff=133197136&oldid=133196380
#
#
#
#
# ___________________________________________________________________________________
# ___________________________________Remaining items: 20___________________________________
# ___________________________________________________________________________________
#
#
#
# sample_id 	 p89755p107570_1502611
# timestamp 	 2013-06-29T08:52:03Z
#
#
# username 	 109.10.56.169
# 	 	 >>> NON registered user
#
# comment 	 /* De Korn III : Remember Who You Are à aujourd'hui */
#
# title    	 Korn
# link      	 https://fr.wikipedia.org/w/index.php?diff=94522637&oldid=94522466
#
#
#
#
# ___________________________________________________________________________________
# ___________________________________Remaining items: 19___________________________________
# ___________________________________________________________________________________
#
#
#
# sample_id 	 p89755p107570_463732
# timestamp 	 2013-04-17T09:07:45Z
#
#
# username 	 Geravion
# 	 	 >>> registered user
# comment
#
# title    	 Ambrose Bierce
# link      	 https://fr.wikipedia.org/w/index.php?diff=92172825&oldid=92080967
#
#
#
#
# ___________________________________________________________________________________
# ___________________________________Remaining items: 18___________________________________
# ___________________________________________________________________________________
#
#
#
# sample_id 	 p89755p107570_741801
# timestamp 	 2013-05-10T20:13:59Z
#
#
# username 	 83.156.212.6
# 	 	 >>> NON registered user
#
# comment 	 /* Répertoires traditionnels */
#
# title    	 Mazurka
# link      	 https://fr.wikipedia.org/w/index.php?diff=92968067&oldid=91095666
#
#
#
#
# ___________________________________________________________________________________
# ___________________________________Remaining items: 17___________________________________
# ___________________________________________________________________________________
#
#
#
# sample_id 	 p89755p107570_1213478
# timestamp 	 2011-07-25T18:49:42Z
#
#
# username 	 88.162.9.117
# 	 	 >>> NON registered user
#
# comment 	 /* Géographie */
#
# title    	 Irigny
# link      	 https://fr.wikipedia.org/w/index.php?diff=67792746&oldid=67489530
#
#
#
#
# ___________________________________________________________________________________
# ___________________________________Remaining items: 16___________________________________
# ___________________________________________________________________________________
#
#
#
# sample_id 	 p89755p107570_1501504
# timestamp 	 2008-01-17T16:12:01Z
#
#
# username 	 Zouavman Le Zouave
# 	 	 >>> registered user
# comment 	 Corrections diverses
#
# title    	 Nokturnal Mortum
# link      	 https://fr.wikipedia.org/w/index.php?diff=25087330&oldid=25081543
#
#
#
#
# ___________________________________________________________________________________
# ___________________________________Remaining items: 15___________________________________
# ___________________________________________________________________________________
#
#
#
# sample_id 	 p89755p107570_440578
# timestamp 	 2009-07-08T17:53:23Z
#
#
# username 	 Muy
# 	 	 >>> registered user
# comment 	 [[User:EDUCA33E/LiveRC/Documentation|LiveRC]] : Révocation des modifications de [[Special:Contributions/Jedeondelatour|Jedeondelatour]]; retour à la version de [[User:Jedeondelatour|Jedeondelatour]]
#
# title    	 Jörg Haider
# link      	 https://fr.wikipedia.org/w/index.php?diff=42796373&oldid=42796363
#
#
#
#
# ___________________________________________________________________________________
# ___________________________________Remaining items: 14___________________________________
# ___________________________________________________________________________________
#
#
#
# sample_id 	 p89755p107570_597336
# timestamp 	 2009-12-11T02:41:25Z
#
#
# username 	 69.159.118.94
# 	 	 >>> NON registered user
#
# comment 	 /* Système nerveux autonome */
#
# title    	 Système nerveux périphérique
# link      	 https://fr.wikipedia.org/w/index.php?diff=47622522&oldid=47169805
#
#
#
#
# ___________________________________________________________________________________
# ___________________________________Remaining items: 13___________________________________
# ___________________________________________________________________________________
#
#
#
# sample_id 	 p89755p107570_1095571
# timestamp 	 2009-09-10T14:44:34Z
#
#
# username 	 Bapti
# 	 	 >>> registered user
# comment 	 /* Biographie */ précision sur septembre 2009
#
# title    	 Karl Zéro
# link      	 https://fr.wikipedia.org/w/index.php?diff=44690509&oldid=44496201
#
#
#
#
# ___________________________________________________________________________________
# ___________________________________Remaining items: 12___________________________________
# ___________________________________________________________________________________
#
#
#
# sample_id 	 p89755p107570_158565
# timestamp 	 2011-07-11T09:24:29Z
#
#
# username 	 92.161.79.42
# 	 	 >>> NON registered user
#
# comment 	 /* Origine du terme */
#
# title    	 Malgré-nous
# link      	 https://fr.wikipedia.org/w/index.php?diff=67342063&oldid=67232319
#
#
#
#
# ___________________________________________________________________________________
# ___________________________________Remaining items: 11___________________________________
# ___________________________________________________________________________________
#
#
#
# sample_id 	 p89755p107570_836334
# timestamp 	 2007-04-17T11:55:31Z
#
#
# username 	 Frenchelection
# 	 	 >>> registered user
# comment
#
# title    	 René-Théophile-Hyacinthe Laennec
# link      	 https://fr.wikipedia.org/w/index.php?diff=15991806&oldid=15991778
#
#
#
#
# ___________________________________________________________________________________
# ___________________________________Remaining items: 10___________________________________
# ___________________________________________________________________________________
#
#
#
# sample_id 	 p107571p128187_464917
# timestamp 	 2008-12-07T10:34:31Z
#
#
# username 	 Yelkrokoyade
# 	 	 >>> registered user
# comment 	 - POV
#
# title    	 Vignoble de Bourgogne
# link      	 https://fr.wikipedia.org/w/index.php?diff=35924678&oldid=35924461
#
#
#
#
# ___________________________________________________________________________________
# ___________________________________Remaining items: 9___________________________________
# ___________________________________________________________________________________
#
#
#
# sample_id 	 p107571p128187_1409484
# timestamp 	 2008-05-20T17:32:45Z
#
#
# username 	 Cybertib
# 	 	 >>> registered user
# comment 	 /* Mixage des pistes */
#
# title    	 Ingénieur du son
# link      	 https://fr.wikipedia.org/w/index.php?diff=29783816&oldid=29783606
#
#
#
#
# ___________________________________________________________________________________
# ___________________________________Remaining items: 8___________________________________
# ___________________________________________________________________________________
#
#
#
# sample_id 	 p107571p128187_573263
# timestamp 	 2016-11-29T05:47:56Z
#
#
# username 	 2003:6B:609:1000:8195:164F:997E:2E17
# 	 	 >>> NON registered user
#
# comment 	 /* Matériel roulant */
#
# title    	 Autobus de Lyon
# link      	 https://fr.wikipedia.org/w/index.php?diff=132243239&oldid=132228094
#
#
#
#
# ___________________________________________________________________________________
# ___________________________________Remaining items: 7___________________________________
# ___________________________________________________________________________________
#
#
#
# sample_id 	 p107571p128187_1020191
# timestamp 	 2010-08-10T19:17:44Z
#
#
# username 	 Roucas
# 	 	 >>> registered user
# comment 	 /* Minéralogiste */
#
# title    	 Vladimir Vernadski
# link      	 https://fr.wikipedia.org/w/index.php?diff=56022162&oldid=56022113
#
#
#
#
# ___________________________________________________________________________________
# ___________________________________Remaining items: 6___________________________________
# ___________________________________________________________________________________
#
#
#
# sample_id 	 p107571p128187_1477095
# timestamp 	 2006-10-28T21:22:42Z
#
#
# username 	 Gene.arboit
# 	 	 >>> registered user
# comment 	 /* Sens du terme */ lien interne
#
# title    	 Wicca
# link      	 https://fr.wikipedia.org/w/index.php?diff=11248798&oldid=11183213
#
#
#
#
# ___________________________________________________________________________________
# ___________________________________Remaining items: 5___________________________________
# ___________________________________________________________________________________
#
#
#
# sample_id 	 p107571p128187_229670
# timestamp 	 2013-03-12T20:58:18Z
#
#
# username 	 Salsero35
# 	 	 >>> registered user
# comment 	 Ajout d’infos. Application de [[WP:NHP]]
#
# title    	 La Garçonne
# link      	 https://fr.wikipedia.org/w/index.php?diff=89869995&oldid=89813086
#
#
#
#
# ___________________________________________________________________________________
# ___________________________________Remaining items: 4___________________________________
# ___________________________________________________________________________________
#
#
#
# sample_id 	 p107571p128187_144850
# timestamp 	 2007-07-18T13:21:10Z
#
#
# username 	 0000
# 	 	 >>> registered user
# comment 	 /* Animal de compagnie */
#
# title    	 Mus musculus
# link      	 https://fr.wikipedia.org/w/index.php?diff=18905059&oldid=18904820
#
#
#
#
# ___________________________________________________________________________________
# ___________________________________Remaining items: 3___________________________________
# ___________________________________________________________________________________
#
#
#
# sample_id 	 p107571p128187_992324
# timestamp 	 2014-12-04T05:34:58Z
#
#
# username 	 88.122.68.178
# 	 	 >>> NON registered user
#
# comment 	 /* Élément moral */  jai mit du bin
#
# title    	 Infraction en droit pénal français
# link      	 https://fr.wikipedia.org/w/index.php?diff=109662925&oldid=105033962
#
#
#
#
# ___________________________________________________________________________________
# ___________________________________Remaining items: 2___________________________________
# ___________________________________________________________________________________
#
#
#
# sample_id 	 p107571p128187_822155
# timestamp 	 2010-02-24T17:29:59Z
#
#
# username 	 Philippe Pierre CAMPION
# 	 	 >>> registered user
# comment 	 /* De la République en armes à la prise du pouvoir par un militaire (1792-1804) */
#
# title    	 Régime républicain en France
# link      	 https://fr.wikipedia.org/w/index.php?diff=50412176&oldid=50350251
#
#
#
#
# ___________________________________________________________________________________
# ___________________________________Remaining items: 1___________________________________
# ___________________________________________________________________________________
#
#
#
# sample_id 	 p107571p128187_770692
# timestamp 	 2015-04-08T04:30:36Z
#
#
# username 	 173.177.125.106
# 	 	 >>> NON registered user
#
# comment
#
# title    	 Grover Cleveland
# link      	 https://fr.wikipedia.org/w/index.php?diff=113643856&oldid=113252169
#
#
#
#
# ___________________________________________________________________________________
# ___________________________________Remaining items: 0___________________________________
# ___________________________________________________________________________________

# %% [markdown]
# ## Annotations retrieval

# %% [markdown]
# Once the *post_annot* outputfile is generated by **InterfaceAnnotation.exe**, it is loaded as a pandas dataframe in which the last column contains all labels applied to the sample.

# %%
def csv_extractor(path, filename):
    df = pd.read_csv(path + filename, sep=';', header=None)
    df.columns = ['index', 'sample_id', 'raw_annot']
    print('Shape:', df.shape)
    return df

# %%
raw_annot = 'data_v1/old_10_19/10_19_post_annot_O_old.csv'
path = '/media/hdd/salaun/wikiedit/annotations/'
df_post_annot = csv_extractor(path, raw_annot)
df_post_annot.tail()
# Out:
# Shape: (100, 3)
#     index               sample_id        raw_annot
# 95     95   p356266p389955_596936  ortho_gram_typo
# 96     96   p356266p389955_811883      new_content
# 97     97   p356266p389955_529934  ortho_gram_typo
# 98     98  p356266p389955_1120258   update_content
# 99     99   p356266p389955_386533  wiki_formatting

# %% [markdown]
# Distinct columns are made for each of labels contained in **raw_annot** column.

# %%
labels_list = ['ortho_gram_typo', 'wiki_formatting', 'vandal', 'reordering', 'revert_vandal', 'revert_other', 'content_remove', 'content_add', 'nbr_wr', 'nbr_rw', 'nbr_x', 'semant_simil', 'semant_diff', 'other']

def label_extractor(df):
    print('Shape of df_post_annot:', df.shape)
    
    for label in labels_list:
        df[label] = df.raw_annot.str.contains(label)
        
    for label in ['nbr', 'semant']:
        df[label] = df.raw_annot.str.contains(label)
    
    for row in range(len(df)):
        if df.loc[row, 'nbr'] or df.loc[row, 'semant']:
            df.loc[row, 'nbr_or_semant'] = True
        else:
            df.loc[row, 'nbr_or_semant'] = False
       
    return df

# %%
df_post_annot = label_extractor(df_post_annot)
df_post_annot.tail()
# Out:
# Shape of df_post_annot: (100, 3)
#     index               sample_id        raw_annot  ortho_gram_typo  \
# 95     95   p356266p389955_596936  ortho_gram_typo             True
# 96     96   p356266p389955_811883      new_content            False
# 97     97   p356266p389955_529934  ortho_gram_typo             True
# 98     98  p356266p389955_1120258   update_content            False
# 99     99   p356266p389955_386533  wiki_formatting            False
#
#     wiki_formatting  vandal  reordering  revert_vandal  revert_other  \
# 95            False   False       False          False         False
# 96            False   False       False          False         False
# 97            False   False       False          False         False
# 98            False   False       False          False         False
# 99             True   False       False          False         False
#
#     content_remove  content_add  nbr_wr  nbr_rw  nbr_x  semant_simil  \
# 95           False        False   False   False  False         False
# 96           False        False   False   False  False         False
# 97           False        False   False   False  False         False
# 98           False        False   False   False  False         False
# 99           False        False   False   False  False         False
#
#     semant_diff  other    nbr  semant  nbr_or_semant
# 95        False  False  False   False          False
# 96        False  False  False   False          False
# 97        False  False  False   False          False
# 98        False  False  False   False          False
# 99        False  False  False   False          False

# %% [markdown]
# ### Summary statistics for all labels

# %%
labels_list_expand = labels_list + ['nbr', 'semant', 'nbr_or_semant']

def labels_sum_stats(df):
    
    df_sum_stats = pd.DataFrame(index=labels_list_expand, columns=['Absolute number', 'Share of all observations'])
    
    for label in labels_list_expand:
        df_sum_stats.loc[label, 'Absolute number'] = df[label].sum()
        df_sum_stats.loc[label, 'Share of all observations'] = df[label].sum() / len(df)
        
    return df_sum_stats

# %%
labels_sum_stats(df_post_annot)
# Out:
#                 Absolute number Share of all observations
# ortho_gram_typo              24                      0.24
# wiki_formatting              27                      0.27
# vandal                       10                       0.1
# reordering                    7                      0.07
# revert_vandal                 6                      0.06
# revert_other                  0                         0
# content_remove                0                         0
# content_add                   0                         0
# nbr_wr                        2                      0.02
# nbr_rw                        1                      0.01
# nbr_x                         0                         0
# semant_simil                  5                      0.05
# semant_diff                   3                      0.03
# other                         5                      0.05
# nbr                           3                      0.03
# semant                        8                      0.08
# nbr_or_semant                11                      0.11

# %% [markdown]
# ### Inter-annotators agreement

# %%
raw_annotO = 'data_v1/old_10_19/10_19_post_annot_O_old.csv'
raw_annotS = 'data_v1/old_10_19/10_19_post_annot_S_old.csv'

df_annot_O = csv_extractor(path, raw_annotO)
df_annot_S = csv_extractor(path, raw_annotS)

df_annot_O = label_extractor(df_annot_O)
df_annot_S = label_extractor(df_annot_S)
# Out:
# Shape: (100, 3)
# Shape: (100, 3)
# Shape of df_post_annot: (100, 3)
# Shape of df_post_annot: (100, 3)

# %%
def cohen_kappa_score_calculator(df1, df2):
    mat1 = df1.loc[:,'ortho_gram_typo':'nbr_or_semant'].as_matrix().astype(np.int)
    mat2 = df2.loc[:,'ortho_gram_typo':'nbr_or_semant'].as_matrix().astype(np.int)
    
    df_kappa_scores = pd.DataFrame(index=labels_list_expand, columns=['kappa score'])
    cohen_kappa_score_array = np.array([])
    
    for i in range(len(labels_list_expand)):
        df_kappa_scores.loc[labels_list_expand[i],'kappa score'] = '{:.2f}'.format(cohen_kappa_score(mat1[:,i], mat2[:,i]))
        cohen_kappa_score_array = np.append(cohen_kappa_score_array, cohen_kappa_score(mat1[:,i], mat2[:,i]))
        
    print("Gross average: %0.2f (+/- %0.2f)" % (cohen_kappa_score_array[~np.isnan(cohen_kappa_score_array)].mean(), cohen_kappa_score_array[~np.isnan(cohen_kappa_score_array)].std()))
    
    return df_kappa_scores

# %%
cohen_kappa_score_calculator(df_annot_O, df_annot_S)
# Out:
# Gross average: 0.32 (+/- 0.30)
# /home/dp/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:370: RuntimeWarning: invalid value encountered in true_divide
#   k = np.sum(w_mat * confusion) / np.sum(w_mat * expected)
#                 kappa score
# ortho_gram_typo        0.40
# wiki_formatting        0.41
# vandal                 0.39
# reordering             0.65
# revert_vandal          0.00
# revert_other           0.00
# content_remove          nan
# content_add             nan
# nbr_wr                 0.80
# nbr_rw                 0.00
# nbr_x                   nan
# semant_simil           0.17
# semant_diff            0.11
# other                  0.10
# nbr                    1.00
# semant                 0.20
# nbr_or_semant          0.29
